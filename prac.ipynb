# %% [markdown]
# <a href="https://colab.research.google.com/github/Maanvijangir/Github-demo/blob/main/prac.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
cd /content/drive/MyDrive/programs
# Out:
# /content/drive/MyDrive/programs

# %%
# !gcc count.c -lm

# %%
# !./a.out
# Out:
# ^C

# %%
# !gcc hello.c -lm

# %%
# !./a.out
# Out:
# Hello world....
